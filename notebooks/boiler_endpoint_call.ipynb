# %%
from ecommerce_agent.agent.factory import agent
from agents import Runner

# %%
import requests

response = requests.post(
    "http://localhost:8000/ask",
    json={"question": "What tools do you use?"}
)
result = response.json()
print(result["answer"])
# Out:
# I have access to a few tools that can assist with tasks such as adding numbers together or getting the current weather for a given city. Would you like to see an example of using one of these tools? For instance, I could fetch the current weather in a specific city if you're interested in that. Could you please provide me with a city name?
