# %%
from ecommerce_agent.agent.factory import agent
from agents import Runner

# %%
#working
#result = await Runner.run(agent, "What tools can you use?")
#print(result.final_output)

# %% [markdown]
# ## Test Google doc integration

# %%
from ecommerce_agent.integrations.google_docs import get_doc_text

doc_id = "1FlKHKxwltF_2S9ADmkfT3B0ajapSMrVKYWRUXf13mno"
creds_path = "secrets/google_service_account.json"

# %%
text = get_doc_text(doc_id, creds_path)
print(text)
# Out:
# # Frequently Asked Questions
# This document contains a list of frequently asked questions.
#
#
# ## How long does shipping take?
# Standard shipping takes 3–5 business days; express is 1–2 business days.
#
# ## Do you ship internationally?
# No, we only ship within Argentina.
#
# ## How much does shipping cost?
# Orders over $50 ship free; otherwise a flat $5.99 fee applies.
#
# ## Can I track my order?
# Yes, you'll receive a tracking link by email once your order ships.
#
# ## How do I find the right size for my child?
# Check our size chart — we recommend measuring height and chest rather than going by age, since kids' proportions vary.
#
# ## What if the size doesn't fit?
# Free exchanges within 30 days — just choose a new size at checkout on your return.
#
# ## What's your return policy?
# Unworn items with tags can be returned within 30 days for a full refund.
#
# ## Can I return sale items?
# Sale items are final sale / eligible for store credit only.
#
# ## How do I start a return?
# Use the "Returns" link in your order confirmation email, or enter your order number on our returns portal.
#
# ## Who pays for return shipping?
# Returns due to product defects are on us; all other returns are paid by the customer.
#
# ## Are your fabrics safe for sensitive skin?
# Yes — our fabrics are OEKO-TEX certified and free of harsh dyes and chemicals.
#
# ## How should I wash these clothes?
# Machine wash cold, tumble dry low. Check the care label for specific items (some prints are wash-cold-only).
#
# ## What payment methods do you accept?
# Visa, Mastercard, Amex, PayPal, Apple Pay, and Shop Pay.
#
# ## Can I change or cancel my order after placing it?
# Orders can be changed within 1 hour of placing them — after that, they're already in fulfillment.
#
# ## Do you offer gift cards?
# Yes, digital gift cards from $25–$200 are available.
#
# ## Do I need an account to order?
# No, guest checkout is available, but an account lets you track orders and save favorites.
#
# ## How do I contact customer service?
# Chat with us here, email support@jonas-demo.com, or call 1-800-JONAS-DEMO, Mon–Fri 9am–6pm.

# %% [markdown]
# ## Test Embeddings and Search Tools

# %%
from ecommerce_agent.retrieval import search_products
from ecommerce_agent.ingest import update_embedding

# update_embedding("SKU-005")

# %%
results = search_products("busco un regalo para mi papa", top_k=5)

for r in results:
    print(r["sku"], "-", r["description"])
# Out:
# G-001 - LOVE VEST — Discount, Winter, Girls, 50% off.
# G-002 - JR HARBIN VEST — Discount, Winter, Girls, 50% off.
# G-007 - PRINT JACKET — Discount, Winter, Girls, 40% off.
# G-005 - TURKEY JACKET — Discount, Winter, Girls, 40% off.
# G-006 - TURKEY JACKET — Discount, Winter, Girls, 40% off.

# %%
results
# Out:
# [{'sku': 'G-001',
#   'name': 'LOVE VEST',
#   'price': '$34.950',
#   'description': 'LOVE VEST — Discount, Winter, Girls, 50% off.'},
#  {'sku': 'G-002',
#   'name': 'JR HARBIN VEST',
#   'price': '$36.950',
#   'description': 'JR HARBIN VEST — Discount, Winter, Girls, 50% off.'},
#  {'sku': 'G-007',
#   'name': 'PRINT JACKET',
#   'price': '$57.540',
#   'description': 'PRINT JACKET — Discount, Winter, Girls, 40% off.'},
#  {'sku': 'G-005',
#   'name': 'TURKEY JACKET',
#   'price': '$62.940',
#   'description': 'TURKEY JACKET — Discount, Winter, Girls, 40% off.'},
#  {'sku': 'G-006',
#   'name': 'TURKEY JACKET',
#   'price': '$56.940',
#   'description': 'TURKEY JACKET — Discount, Winter, Girls, 40% off.'}]

# %%
from ecommerce_agent.retrieval import list_documents, search_documents

print("Catalog:")
for doc in list_documents():
    print(doc)
# Out:
# Catalog:

# %%
results = search_documents("How do I contact customer service?", top_k=5)

for r in results:
    print(f"[{r['filename']}] chunk {r['chunk_index']}")
    print(r["content"][:400])
    print()

# %%
# Same search, but only inside the Google Doc ingested above
results = search_documents(
    "How do I contact customer service?",
    top_k=5,
    document_id=doc_id,
)

for r in results:
    print(f"[{r['document_id']}] chunk {r['chunk_index']}")
    print(r["content"][:500])
    print()
# Out:
# [1FlKHKxwltF_2S9ADmkfT3B0ajapSMrVKYWRUXf13mno] chunk 0
# Frequently Asked Questions
# Shipping & Delivery
# How long does shipping take? Standard shipping takes 3–5 business days; express is 1–2 business days.
#
# Do you ship internationally? No, we only ship within Argentina.
#
# How much does shipping cost? Orders over $50 ship free; otherwise a flat $5.99 fee applies.
#
# Can I track my order? Yes, you'll receive a tracking link by email once your order ships.
# Sizing & Fit
# How do I find the right size for my child? Check our size chart — we recommend measuring
